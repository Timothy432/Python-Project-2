# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
iris  = pd.read_csv('file:///C:/Users/Timothy/OneDrive/Documents/Banjir1.csv')

# %%
iris.head()
# Out:
#    Tahun  Sumatra  Jawa  Bali & NTB  Sulawesi  Kalimantan  Maluku  Papua
# 0   2010        5     6           1         0           2       1      1
# 1   2011        4     4           3         0           2       0      1
# 2   2012        8     2           2         0           1       0      1
# 3   2013        3     6           1         0           0       1      0
# 4   2014        4     9           0         0           1       2      0

# %%
iris.tail()
# Out:
#    Tahun  Sumatra  Jawa  Bali & NTB  Sulawesi  Kalimantan  Maluku  Papua
# 5   2015        4     6           3         1           4       5      3
# 6   2016        5     3           3         0           0       3      1
# 7   2017        8     6           2         0           2       4      1
# 8   2018        3     8           7         0           5       1      3
# 9   2019        3     3           3         0           1       3      0

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
# Tahun         10 non-null int64
# Sumatra       10 non-null int64
# Jawa          10 non-null int64
# Bali & NTB    10 non-null int64
# Sulawesi      10 non-null int64
# Kalimantan    10 non-null int64
# Maluku        10 non-null int64
# Papua         10 non-null int64
# dtypes: int64(8)
# memory usage: 768.0 bytes

# %%
iris.describe()
# Out:
#             Tahun    Sumatra       Jawa  Bali & NTB   Sulawesi  Kalimantan  \
# count    10.00000  10.000000  10.000000   10.000000  10.000000   10.000000
# mean   2014.50000   4.700000   5.300000    2.500000   0.100000    1.800000
# std       3.02765   1.888562   2.263233    1.900292   0.316228    1.619328
# min    2010.00000   3.000000   2.000000    0.000000   0.000000    0.000000
# 25%    2012.25000   3.250000   3.250000    1.250000   0.000000    1.000000
# 50%    2014.50000   4.000000   6.000000    2.500000   0.000000    1.500000
# 75%    2016.75000   5.000000   6.000000    3.000000   0.000000    2.000000
# max    2019.00000   8.000000   9.000000    7.000000   1.000000    5.000000
#
#           Maluku      Papua
# count  10.000000  10.000000
# mean    2.000000   1.100000
# std     1.699673   1.100505
# min     0.000000   0.000000
# 25%     1.000000   0.250000
# 50%     1.500000   1.000000
# 75%     3.000000   1.000000
# max     5.000000   3.000000

# %%
iris.groupby('Sumatra').mean()
# Out:
#                Tahun      Jawa  Bali & NTB  Sulawesi  Kalimantan    Maluku  \
# Sumatra
# 3        2016.666667  5.666667    3.666667  0.000000    2.000000  1.666667
# 4        2013.333333  6.333333    2.000000  0.333333    2.333333  2.333333
# 5        2013.000000  4.500000    2.000000  0.000000    1.000000  2.000000
# 8        2014.500000  4.000000    2.000000  0.000000    1.500000  2.000000
#
#             Papua
# Sumatra
# 3        1.000000
# 4        1.333333
# 5        1.000000
# 8        1.000000

# %%
iris.groupby('Jawa').mean()
# Out:
#         Tahun  Sumatra  Bali & NTB  Sulawesi  Kalimantan  Maluku  Papua
# Jawa
# 2     2012.00      8.0        2.00      0.00         1.0    0.00   1.00
# 3     2017.50      4.0        3.00      0.00         0.5    3.00   0.50
# 4     2011.00      4.0        3.00      0.00         2.0    0.00   1.00
# 6     2013.75      5.0        1.75      0.25         2.0    2.75   1.25
# 8     2018.00      3.0        7.00      0.00         5.0    1.00   3.00
# 9     2014.00      4.0        0.00      0.00         1.0    2.00   0.00

# %%
iris.groupby('Bali & NTB').mean()
# Out:
#               Tahun  Sumatra  Jawa  Sulawesi  Kalimantan  Maluku  Papua
# Bali & NTB
# 0           2014.00      4.0   9.0      0.00        1.00    2.00   0.00
# 1           2011.50      4.0   6.0      0.00        1.00    1.00   0.50
# 2           2014.50      8.0   4.0      0.00        1.50    2.00   1.00
# 3           2015.25      4.0   4.0      0.25        1.75    2.75   1.25
# 7           2018.00      3.0   8.0      0.00        5.00    1.00   3.00

# %%
iris.groupby('Sulawesi').mean()
# Out:
#                 Tahun   Sumatra      Jawa  Bali & NTB  Kalimantan    Maluku  \
# Sulawesi
# 0         2014.444444  4.777778  5.222222    2.444444    1.555556  1.666667
# 1         2015.000000  4.000000  6.000000    3.000000    4.000000  5.000000
#
#              Papua
# Sulawesi
# 0         0.888889
# 1         3.000000

# %%
iris.groupby('Kalimantan').mean()
# Out:
#                   Tahun   Sumatra      Jawa  Bali & NTB  Sulawesi    Maluku  \
# Kalimantan
# 0           2014.500000  4.000000  4.500000    2.000000       0.0  2.000000
# 1           2015.000000  5.000000  4.666667    1.666667       0.0  1.666667
# 2           2012.666667  5.666667  5.333333    2.000000       0.0  1.666667
# 4           2015.000000  4.000000  6.000000    3.000000       1.0  5.000000
# 5           2018.000000  3.000000  8.000000    7.000000       0.0  1.000000
#
#                Papua
# Kalimantan
# 0           0.500000
# 1           0.333333
# 2           1.000000
# 4           3.000000
# 5           3.000000

# %%
iris.groupby('Papua').mean()
# Out:
#              Tahun   Sumatra  Jawa  Bali & NTB  Sulawesi  Kalimantan  Maluku
# Papua
# 0      2015.333333  3.333333   6.0    1.333333       0.0    0.666667     2.0
# 1      2013.200000  6.000000   4.2    2.200000       0.0    1.400000     1.6
# 3      2016.500000  3.500000   7.0    5.000000       0.5    4.500000     3.0

# %%
iris.groupby('Tahun').mean()
# Out:
#        Sumatra  Jawa  Bali & NTB  Sulawesi  Kalimantan  Maluku  Papua
# Tahun
# 2010         5     6           1         0           2       1      1
# 2011         4     4           3         0           2       0      1
# 2012         8     2           2         0           1       0      1
# 2013         3     6           1         0           0       1      0
# 2014         4     9           0         0           1       2      0
# 2015         4     6           3         1           4       5      3
# 2016         5     3           3         0           0       3      1
# 2017         8     6           2         0           2       4      1
# 2018         3     8           7         0           5       1      3
# 2019         3     3           3         0           1       3      0

# %%
plt.figure(figsize=(15,7))
plt.plot(iris['Sumatra'], label='Sumatra')
plt.plot(iris['Jawa'], label='Jawa')
plt.plot(iris['Bali & NTB'], label='Bali & NTB')
plt.plot(iris['Sulawesi'], label='Sulawesi')
plt.plot(iris['Kalimantan'], label='Kalimantan')
plt.plot(iris['Maluku'], label='Maluku')
plt.plot(iris['Papua'], label='Papua')

plt.xlabel('Tahun')

plt.ylabel('Jumlah')
plt.title('Data jumlah banjir hyang terjadi setiap daerah tahun 2010-2020')
plt.legend()
plt.show()
